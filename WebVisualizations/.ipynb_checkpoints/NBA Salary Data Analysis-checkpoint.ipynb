# %%
import pandas as pd
import csv
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import linregress

# %%
# source: https://data.world/datadavis/nba-salaries
players_df = pd.read_csv('Resources/players.csv')
salaries_df = pd.read_csv('Resources/salaries_1985to2018.csv')
print(len(players_df))
players_df = players_df.rename(columns={"_id": "player_id"})
players_df.head()
# Out:
# 4685
#    player_id         birthDate              birthPlace  career_AST career_FG%  \
# 0  abdelal01     June 24, 1968            Cairo, Egypt         0.3       50.2
# 1  abdulza01     April 7, 1946      Brooklyn, New York         1.2       42.8
# 2  abdulka01    April 16, 1947      New York, New York         3.6       55.9
# 3  abdulma02     March 9, 1969   Gulfport, Mississippi         3.5       44.2
# 4  abdulta01  November 3, 1974  Maisons Alfort, France         1.1       41.7
#
#   career_FG3% career_FT%  career_G career_PER  career_PTS  ...    draft_pick  \
# 0         0.0       70.1       256       13.0         5.7  ...  25th overall
# 1         NaN       72.8       505       15.1         9.0  ...   5th overall
# 2         5.6       72.1      1560       24.6        24.6  ...   1st overall
# 3        35.4       90.5       586       15.4        14.6  ...   3rd overall
# 4        23.7       70.3       236       11.4         7.8  ...  11th overall
#
#   draft_round              draft_team draft_year height  \
# 0   1st round  Portland Trail Blazers       1990   6-10
# 1   1st round       Cincinnati Royals       1968    6-9
# 2   1st round         Milwaukee Bucks       1969    7-2
# 3   1st round          Denver Nuggets       1990    6-1
# 4   1st round        Sacramento Kings       1997    6-6
#
#                                 highSchool                 name  \
# 0     Bloomfield in Bloomfield, New Jersey       Alaa Abdelnaby
# 1           John Jay in Brooklyn, New York      Zaid Abdul-Aziz
# 2     Power Memorial in New York, New York  Kareem Abdul-Jabbar
# 3        Gulfport in Gulfport, Mississippi   Mahmoud Abdul-Rauf
# 4  Lycee Aristide Briand in Evreux, France    Tariq Abdul-Wahad
#
#                    position shoots weight
# 0             Power Forward  Right  240lb
# 1  Power Forward and Center  Right  235lb
# 2                    Center  Right  225lb
# 3               Point Guard  Right  162lb
# 4            Shooting Guard  Right  223lb
#
# [5 rows x 24 columns]

# %%
salaries_df
# players_df.merge(salaries_df, right_on='player_id')


career_salary_list = []
for player in salaries_df['player_id'].unique():
    this_player = salaries_df.loc[salaries_df["player_id"] == player, :]
    career_earnings = this_player['salary'].sum()
    player_salary_dict = {}
    player_salary_dict['player_id'] = player
    player_salary_dict['career_earnings'] = career_earnings
    career_salary_list.append(player_salary_dict)
    
   

nba_salary_df = pd.DataFrame(data=career_salary_list)

print(len(nba_salary_df))    
nba_salary_df.head()
# Out:
# 2408
#    player_id  career_earnings
# 0  abdelal01          2844000
# 1  abdulka01          8560000
# 2  abdulma02         19849500
# 3  abdulta01         37982800
# 4  abdursh01         95866000

# %%
nba_df = pd.merge(players_df, nba_salary_df, on='player_id')
# nba_df["career_earnings"] = nba_df["career_earnings"].map("${:,}".format)
# nba_df = nba_df['career_WS'].astype('float64').dtypes
nba_df = nba_df.astype({'career_WS': 'float64', 'career_earnings': 'float64', 'draft_year': 'float64'})
nba_df.dtypes
# Out:
# player_id           object
# birthDate           object
# birthPlace          object
# career_AST         float64
# career_FG%          object
# career_FG3%         object
# career_FT%          object
# career_G             int64
# career_PER          object
# career_PTS         float64
# career_TRB          object
# career_WS          float64
# career_eFG%         object
# college             object
# draft_pick          object
# draft_round         object
# draft_team          object
# draft_year         float64
# height              object
# highSchool          object
# name                object
# position            object
# shoots              object
# weight              object
# career_earnings    float64
# dtype: object

# %%
post_merger = pre_merger = nba_df.loc[nba_df["draft_year"] >= 1976, :]
eighties = post_merger.loc[post_merger["draft_year"] < 1990, :]
not_eighties = post_merger.loc[post_merger["draft_year"] >= 1990, :]
nineties = not_eighties.loc[not_eighties["draft_year"] < 2000, :]
not_nineties = not_eighties.loc[not_eighties["draft_year"] >= 2000, :]
aughts = not_nineties.loc[not_nineties["draft_year"] < 2010, :]
tens = not_nineties.loc[not_nineties["draft_year"] >= 2010, :]
pre_merger = nba_df.loc[nba_df["draft_year"] < 1976, :]
aughts.head()
# Out:
#     player_id         birthDate               birthPlace  career_AST  \
# 6   ackeral01  January 21, 1983      Compton, California         0.5
# 10  adamsha01     June 20, 1984    Inglewood, California         0.2
# 17  afflaar01  October 15, 1985  Los Angeles, California         1.8
# 18   agerma01  February 9, 1984        Detroit, Michigan         0.2
# 22  ajincal01       May 6, 1988    Saint-Etienne, France         0.5
#
#    career_FG% career_FG3% career_FT%  career_G career_PER  career_PTS  ...  \
# 6        37.0        32.0       50.0        30        8.5         2.7  ...
# 10       53.4         0.0       64.3        73       11.8         2.5  ...
# 17       45.0        38.6       82.5       762       11.9        10.8  ...
# 18       33.9        25.0       56.6        82        2.8         2.1  ...
# 22       50.3        28.6       79.7       293       14.9         5.3  ...
#
#    draft_round         draft_team draft_year height  \
# 6    2nd round    Detroit Pistons     2005.0    6-5
# 10   2nd round    New Jersey Nets     2006.0    6-4
# 17   1st round    Detroit Pistons     2007.0    6-5
# 18   1st round   Dallas Mavericks     2006.0    6-5
# 22   1st round  Charlotte Bobcats     2008.0    7-2
#
#                                 highSchool           name  \
# 6         Eisenhower in Rialto, California     Alex Acker
# 10  Westchester in Los Angeles, California   Hassan Adams
# 17       Centennial in Compton, California  Arron Afflalo
# 18            Crocket in Detroit, Michigan   Maurice Ager
# 22                                     NaN  Alexis Ajinca
#
#                             position  shoots weight career_earnings
# 6                     Shooting Guard   Right  185lb       1949488.0
# 10                    Shooting Guard   Right  220lb        709881.0
# 17  Shooting Guard and Small Forward   Right  210lb      58852159.0
# 18                    Shooting Guard   Right  202lb       3006625.0
# 22          Power Forward and Center   Right  248lb      18959122.0
#
# [5 rows x 25 columns]

# %%
fig, ax = plt.subplots()

ax.plot(pre_merger['career_WS'], pre_merger['career_earnings'], 'o', color='black', label = 'Pre-Merger (1976)')
ax.plot(eighties['career_WS'], eighties['career_earnings'],'o', color='brown', label = "1976 through '80s")
ax.plot(nineties['career_WS'], nineties['career_earnings'],'o', color='purple', label = '1990s')
ax.plot(aughts['career_WS'], aughts['career_earnings'],'o', color='blue', label = '2000s')
ax.plot(tens['career_WS'], tens['career_earnings'],'o', color='darkgreen', label = '2010s')



plt.title("Wins Shares by Salary")
plt.ylabel("Career Salary ($Hundreds of Millions)")
plt.xlabel("Career Win Shares")
plt.legend(loc='best')
plt.savefig('visualizations/Total')
plt.show()

# %%
def label_point(x, y, val, ax):
    a = pd.concat({'x': x, 'y': y, 'val': val}, axis=1)
    for i, point in a.iterrows():
        ax.text(point['x'], point['y'], str(point['val']))
        
label_point(pre_merger['career_WS'], pre_merger['career_earnings'], pre_merger['name'], ax)

# %%
fig, ax = plt.subplots()

ax.plot(pre_merger['career_WS'], pre_merger['career_earnings'], 'o', color='black', linewidth=0, label = 'Pre-Merger (1976)')
label_point(pre_merger['career_WS'], pre_merger['career_earnings'], pre_merger['name'], ax)

(slope, intercept, _, _, _) = linregress(pre_merger['career_WS'], pre_merger['career_earnings'])
fit = slope * pre_merger['career_WS'] + intercept
ax.plot(pre_merger['career_WS'], fit, '-', color='black')

plt.title("Wins Shares by Salary Pre-Merger (Drafted Before 1976)")
plt.ylabel("Career Salary ($)")
plt.xlabel("Career Win Shares")
plt.savefig('visualizations/PreMerger')
plt.show()

# %%
pre_merger['fit'] = fit
pre_merger['overpaid/underpaid'] = pre_merger['career_earnings']-pre_merger['fit']
pre_merger['percent_overpaid/underpaid'] = pre_merger['overpaid/underpaid']/pre_merger['fit']

pre_merger = pre_merger.sort_values(by=['percent_overpaid/underpaid'], ascending=False)
pre_merger = pre_merger.sort_values(by=['percent_overpaid/underpaid'], ascending=True)
pre_merger = pre_merger.sort_values(by=['overpaid/underpaid'], ascending=False)
pre_merger = pre_merger.sort_values(by=['overpaid/underpaid'], ascending=True)

pre_merger.head()
# Out:
# //anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# //anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# //anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-1c773a0ff91c> in <module>
#       4
#       5 pre_merger = pre_merger.sort_values(by=['percent_overpaid/underpaid'], ascending=False)
# ----> 6 pre_merger = pre_mergers.sort_values(by=['percent_overpaid/underpaid'], ascending=True)
#       7 pre_merger = pre_merger.sort_values(by=['overpaid/underpaid'], ascending=False)
#       8 pre_merger = pre_merger.sort_values(by=['overpaid/underpaid'], ascending=True)
#
# NameError: name 'pre_mergers' is not defined

# %%
fig, ax = plt.subplots()

ax.plot(eighties['career_WS'], eighties['career_earnings'],'o', color='brown', label = "1976 through '80s")
label_point(eighties['career_WS'], eighties['career_earnings'], eighties['name'], ax)

(slope, intercept, _, _, _) = linregress(eighties['career_WS'], eighties['career_earnings'])
fit = slope * eighties['career_WS'] + intercept
ax.plot(eighties['career_WS'], fit, '-', color='red')

plt.title("Wins Shares by Salary (Drafted 1980-1989)")
plt.ylabel("Career Salary ($Hundreds of Millions)")
plt.xlabel("Career Win Shares")
plt.savefig('visualizations/Eighties')
plt.show()

# %%
eighties['fit'] = fit
eighties['overpaid/underpaid'] = eighties['career_earnings']-eighties['fit']
eighties['percent_overpaid/underpaid'] = eighties['overpaid/underpaid']/eighties['fit']

eighties = eighties.sort_values(by=['percent_overpaid/underpaid'], ascending=False)
eighties = eighties.sort_values(by=['percent_overpaid/underpaid'], ascending=True)
eighties = eighties.sort_values(by=['overpaid/underpaid'], ascending=False)
eighties = eighties.sort_values(by=['overpaid/underpaid'], ascending=True)

eighties.head()
# Out:
#       player_id          birthDate                        birthPlace  \
# 477   dantlad01  February 28, 1956  Washington, District of Columbia
# 1104  johnsma02    August 14, 1959                 Lansing, Michigan
# 375   cheekma01  September 8, 1956                 Chicago, Illinois
# 1930  sikmaja01  November 14, 1955                Kankakee, Illinois
# 1224  laimbbi01       May 19, 1957             Boston, Massachusetts
#
#       career_AST career_FG% career_FG3% career_FT%  career_G career_PER  \
# 477          3.0       54.0        17.1       81.8       955       21.5
# 1104        11.2       52.0        30.3       84.8       906       24.1
# 375          6.7       52.3        25.5       79.3      1101       16.5
# 1930         3.2       46.4        32.8       84.9      1107       17.3
# 1224         2.0       49.8        32.6       83.7      1068       16.1
#
#       career_PTS  ... height                                 highSchool  \
# 477         24.3  ...    6-5  DeMatha Catholic in Hyattsville, Maryland
# 1104        19.5  ...    6-9               Everett in Lansing, Michigan
# 375         11.1  ...    6-1              Du Sable in Chicago, Illinois
# 1930        15.6  ...   6-11         Saint Anne in Saint Anne, Illinois
# 1224        12.9  ...   6-11   Palos Verdes in Palos Verdes, California
#
#                 name                                          position shoots  \
# 477   Adrian Dantley                                     Small Forward  Right
# 1104   Magic Johnson  Shooting Guard and Power Forward and Point Guard  Right
# 375   Maurice Cheeks                                       Point Guard  Right
# 1930      Jack Sikma                                            Center  Right
# 1224   Bill Laimbeer                                            Center  Right
#
#      weight career_earnings           fit overpaid/underpaid  \
# 477   208lb       4065000.0  4.609606e+07      -4.203106e+07
# 1104  215lb      23642860.0  5.376021e+07      -3.011735e+07
# 375   180lb       5345000.0  3.520303e+07      -2.985803e+07
# 1930  230lb       8749000.0  3.839642e+07      -2.964742e+07
# 1224  245lb       7888000.0  3.594815e+07      -2.806015e+07
#
#      percent_overpaid/underpaid
# 477                   -0.911815
# 1104                  -0.560216
# 375                   -0.848166
# 1930                  -0.772140
# 1224                  -0.780573
#
# [5 rows x 28 columns]

# %%
fig, ax = plt.subplots()

ax.plot(nineties['career_WS'], nineties['career_earnings'],'o', color='purple', label = '1990s')
label_point(nineties['career_WS'], nineties['career_earnings'], nineties['name'], ax)

(slope, intercept, _, _, _) = linregress(nineties['career_WS'], nineties['career_earnings'])
fit = slope * nineties['career_WS'] + intercept
ax.plot(nineties['career_WS'], fit, '-', color='purple')

plt.title("Wins Shares by Salary (Drafted 1990-1999)")
plt.ylabel("Career Salary ($Hundreds of Millions)")
plt.xlabel("Career Win Shares")

plt.savefig('visualizations/Nineties')
plt.show()

# %%
nineties['fit'] = fit
nineties['overpaid/underpaid'] = nineties['career_earnings']-nineties['fit']
nineties['percent_overpaid/underpaid'] = nineties['overpaid/underpaid']/nineties['fit']

nineties = nineties.sort_values(by=['percent_overpaid/underpaid'], ascending=False)
# nineties = nineties.sort_values(by=['percent_overpaid/underpaid'], ascending=True)
# nineties = nineties.sort_values(by=['overpaid/underpaid'], ascending=False)
# nineties = nineties.sort_values(by=['overpaid/underpaid'], ascending=True)

nineties.head()
# Out:
# //anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# //anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# //anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#       player_id          birthDate               birthPlace  career_AST  \
# 1744  radojal01     August 8, 1976  Herceg Novi, Montenegro         0.5
# 1609  olivebr01       June 1, 1968        Chicago, Illinois         1.0
# 1047  jamesje01  November 17, 1975           Tampa, Florida         0.3
# 1613  olowomi01      April 3, 1975           Lagos, Nigeria         0.7
# 1323  maconma01     April 14, 1969        Saginaw, Michigan         1.7
#
#      career_FG% career_FG3% career_FT%  career_G career_PER  career_PTS  ...  \
# 1744       30.8           -       62.5        15       -0.9         1.7  ...
# 1609       38.8        22.7       70.5       118        8.1         3.3  ...
# 1047       48.5         0.0       61.7       358       10.6         4.3  ...
# 1613       43.5           -       59.7       500       10.7         8.3  ...
# 1323       38.4        27.0       73.5       251        8.9         6.7  ...
#
#      height                                        highSchool  \
# 1744    7-3                                               NaN
# 1609    6-4                          Wills in Smyrna, Georgia
# 1047    7-0   Pentacostal Christian Academy in Tampa, Florida
# 1613    7-0  Newlands Manorium in East Sussex, United Kingdom
# 1323    6-5                  Buena Vista in Saginaw, Michigan
#
#                       name                        position shoots weight  \
# 1744  Aleksandar Radojevic                          Center  Right  250lb
# 1609          Brian Oliver                  Shooting Guard  Right  210lb
# 1047          Jerome James                          Center  Right  300lb
# 1613    Michael Olowokandi                          Center  Right  269lb
# 1323            Mark Macon  Shooting Guard and Point Guard  Right  185lb
#
#      career_earnings           fit overpaid/underpaid  \
# 1744       4995526.0  3.204684e+05       4.675058e+06
# 1609       1973000.0  1.863758e+05       1.786624e+06
# 1047      44755150.0  4.745523e+06       4.000963e+07
# 1613      37906690.0  4.209153e+06       3.369754e+07
# 1323       7501000.0  9.909313e+05       6.510069e+06
#
#      percent_overpaid/underpaid
# 1744                  14.588201
# 1609                   9.586136
# 1047                   8.431025
# 1613                   8.005776
# 1323                   6.569647
#
# [5 rows x 28 columns]

# %%
fig, ax = plt.subplots()

ax.plot(aughts['career_WS'], aughts['career_earnings'],'o', color='blue', label = '2000s')
label_point(aughts['career_WS'], aughts['career_earnings'], aughts['name'], ax)

plt.title("Wins Shares by Salary (Drafted 2000-2009)")
plt.ylabel("Career Salary ($Hundreds of Millions)")
plt.xlabel("Career Win Shares")

(slope, intercept, _, _, _) = linregress(aughts['career_WS'], aughts['career_earnings'])
fit = slope * aughts['career_WS'] + intercept
ax.plot(aughts['career_WS'], fit, '-', color='blue')

plt.savefig('visualizations/Aughts')
plt.show()

# %%
aughts['fit'] = fit
aughts['overpaid/underpaid'] = aughts['career_earnings']-aughts['fit']
aughts['percent_overpaid/underpaid'] = aughts['overpaid/underpaid']/aughts['fit']

aughts = aughts.sort_values(by=['percent_overpaid/underpaid'], ascending=False)
# aughts = aughts.sort_values(by=['percent_overpaid/underpaid'], ascending=True)
# aughts = aughts.sort_values(by=['overpaid/underpaid'], ascending=False)
# aughts = aughts.sort_values(by=['overpaid/underpaid'], ascending=True)

aughts.head()
# Out:
# //anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# //anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# //anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#       player_id         birthDate               birthPlace  career_AST  \
# 1500  morriad01     July 19, 1984        Glendive, Montana         1.4
# 2143  tskitni01    April 14, 1983         Tbilisi, Georgia         0.7
# 1449  milicda01     June 20, 1985         Novi Sad, Serbia         0.9
# 668   flynnjo01  February 6, 1989  Niagara Falls, New York         3.9
# 1447  milesda01   October 9, 1981     Belleville, Illinois         1.9
#
#      career_FG% career_FG3% career_FT%  career_G career_PER  career_PTS  ...  \
# 1500       37.3        33.1       71.0       161        7.4         7.5  ...
# 2143       30.4        23.5       73.0       172        5.2         2.9  ...
# 1449       46.0         0.0       57.4       468       12.3         6.0  ...
# 668        40.0        33.8       80.9       163       11.3         9.2  ...
# 1447       47.2        16.8       59.0       446       13.9        10.1  ...
#
#      height                                  highSchool                  name  \
# 1500    6-8                 Mead in Spokane, Washington         Adam Morrison
# 2143    7-0                                         NaN  Nikoloz Tskitishvili
# 1449    7-0                 Hemiska in Novi Sad, Serbia         Darko Milicic
# 668     6-0    Niagara Falls in Niagara Falls, New York           Jonny Flynn
# 1447    6-9  East St. Louis in East St. Louis, Illinois          Darius Miles
#
#                              position shoots weight career_earnings  \
# 1500  Small Forward and Power Forward  Right  205lb      16920989.0
# 2143  Small Forward and Power Forward  Right  225lb       8907528.0
# 1449         Power Forward and Center   Left  250lb      52323642.0
# 668                       Point Guard  Right  185lb       9576000.0
# 1447                    Small Forward  Right  210lb      61999973.0
#
#                fit overpaid/underpaid percent_overpaid/underpaid
# 1500  2.168055e+06       1.475293e+07                   6.804686
# 2143  1.887167e+06       7.020361e+06                   3.720053
# 1449  1.410579e+07       3.821785e+07                   2.709372
# 668   2.589387e+06       6.986613e+06                   2.698173
# 1447  1.747645e+07       4.452352e+07                   2.547630
#
# [5 rows x 28 columns]

# %%
fig, ax = plt.subplots()

ax.plot(tens['career_WS'], tens['career_earnings'],'o', color='darkgreen', label = '2010s')
label_point(tens['career_WS'], tens['career_earnings'], tens['name'], ax)

plt.title("Wins Shares by Salary (Drafted 2010-2018)")
plt.ylabel("Career Salary ($Hundreds of Millions)")
plt.xlabel("Career Win Shares")

(slope, intercept, _, _, _) = linregress(tens['career_WS'], tens['career_earnings'])
fit = slope * tens['career_WS'] + intercept
ax.plot(tens['career_WS'], fit, '-', color='darkgreen')
tens['fit'] = fit





plt.savefig('visualizations/Tens')
plt.show()
# Out:
# //anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]

# %%
tens['overpaid/underpaid'] = tens['career_earnings']-tens['fit']
tens['percent_overpaid/underpaid'] = tens['overpaid/underpaid']/tens['fit']

tens = tens.sort_values(by=['percent_overpaid/underpaid'], ascending=False)
tens = tens.sort_values(by=['percent_overpaid/underpaid'], ascending=True)
tens = tens.sort_values(by=['overpaid/underpaid'], ascending=False)
tens = tens.sort_values(by=['overpaid/underpaid'], ascending=True)

tens.head()
# Out:
# //anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# //anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#       player_id          birthDate             birthPlace  career_AST  \
# 1117  jokicni01  February 19, 1995         Sombor, Serbia         5.1
# 2136  townska01  November 15, 1995     Edison, New Jersey         2.6
# 764   goberru01      June 26, 1992  Saint-Quentin, France         1.3
# 336   capelca01       May 18, 1994    Geneva, Switzerland         0.9
# 69    antetgi01   December 6, 1994         Athens, Greece         4.1
#
#      career_FG% career_FG3% career_FT%  career_G career_PER  career_PTS  ...  \
# 1117       52.3        34.5       82.8       308       24.8        16.3  ...
# 2136       53.7        39.2       83.6       323       25.0        22.3  ...
# 764        62.9         0.0       63.1       406       21.5        11.1  ...
# 336        63.5         0.0       52.5       295       22.2        12.0  ...
# 69         52.1        27.7       74.2       465       21.9        18.8  ...
#
#      height                          highSchool                   name  \
# 1117    7-0                                 NaN           Nikola Jokic
# 2136    7-0  St. Joseph in Metuchen, New Jersey     Karl-Anthony Towns
# 764     7-1                                 NaN            Rudy Gobert
# 336    6-10                                 NaN           Clint Capela
# 69     6-11                                 NaN  Giannis Antetokounmpo
#
#                                                position shoots weight  \
# 1117                                             Center  Right  250lb
# 2136                                             Center  Right  248lb
# 764                                              Center  Right  245lb
# 336                                              Center  Right  240lb
# 69    Point Guard and Power Forward and Small Forwar...  Right  242lb
#
#      career_earnings           fit overpaid/underpaid  \
# 1117       4129882.0  4.382376e+07      -3.969387e+07
# 2136      17880600.0  5.082880e+07      -3.294820e+07
# 764       27478087.0  5.880377e+07      -3.132568e+07
# 336        6062680.0  3.574102e+07      -2.967834e+07
# 69        31087051.0  5.923485e+07      -2.814780e+07
#
#      percent_overpaid/underpaid
# 1117                  -0.905762
# 2136                  -0.648219
# 764                   -0.532716
# 336                   -0.830372
# 69                    -0.475190
#
# [5 rows x 28 columns]

# %%
fig, ax = plt.subplots()

ax.plot(pre_merger['career_WS'], pre_merger['career_earnings'], 'o', color='black', label = 'Pre-Merger (1976)')
ax.plot(eighties['career_WS'], eighties['career_earnings'],'o', color='brown', label = "1976 through '80s")
ax.plot(nineties['career_WS'], nineties['career_earnings'],'o', color='purple', label = '1990s')
ax.plot(aughts['career_WS'], aughts['career_earnings'],'o', color='blue', label = '2000s')
ax.plot(tens['career_WS'], tens['career_earnings'],'o', color='darkgreen', label = '2010s')

label_point(pre_merger['career_WS'], pre_merger['career_earnings'], pre_merger['name'], ax)
label_point(eighties['career_WS'], eighties['career_earnings'], eighties['name'], ax)
label_point(nineties['career_WS'], nineties['career_earnings'], nineties['name'], ax)
label_point(aughts['career_WS'], aughts['career_earnings'], aughts['name'], ax)
label_point(tens['career_WS'], tens['career_earnings'], tens['name'], ax)


plt.title("Wins Shares by Salary")
plt.ylabel("Career Salary ($Hundreds of Millions)")
plt.xlabel("Career Win Shares")
plt.legend(loc='best')
plt.savefig('visualizations/Win Shares by Salary - Labelled')
plt.show()
